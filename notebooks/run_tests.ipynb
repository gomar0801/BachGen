# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gomar0801/BachGen/blob/main/notebooks/run_tests.ipynb)

# %%
# %%capture
# Clone the BachGen repository
# !rm -rf BachGen && git clone https://github.com/gomar0801/BachGen.git
# !chmod +x ./BachGen/scripts/setup.sh
# !./BachGen/scripts/setup.sh

# %%
import os
import sys
from pathlib import Path

notebook_dir = Path.cwd()
print(f"Current directory: {notebook_dir}")

# BachGen is cloned into the current directory, not parent
bachgen_path = notebook_dir / "BachGen"
sys.path.insert(0, str(bachgen_path))
print("Added BachGen to Python path")

# Change to BachGen directory and run setup
os.chdir(bachgen_path)
# !python -m pytest -v
# Out:
# Current directory: /Users/raphaelcousin/BachGen/notebooks
# Added BachGen to Python path
# ============================= test session starts ==============================
# platform darwin -- Python 3.13.3, pytest-8.4.1, pluggy-1.6.0 -- /Users/raphaelcousin/Library/Caches/pypoetry/virtualenvs/bachgen-UH23d-R1-py3.13/bin/python
# cachedir: .pytest_cache
# rootdir: /Users/raphaelcousin/BachGen/notebooks/BachGen
# configfile: pyproject.toml
# plugins: anyio-4.9.0
# collected 4 items
#
# tests/test_roundtrip.py::test_xml_to_tokens_to_xml FAILED                [ 25%]
# tests/test_token_to_xml.py::test_minimal_tokens_to_score PASSED          [ 50%]
# tests/test_xml_to_tokens.py::test_minimal_xml_to_tokens FAILED           [ 75%]
# tests/test_xml_to_tokens.py::test_xml_to_tokens_with_note_numbers FAILED [100%]
#
# =================================== FAILURES ===================================
# __________________________ test_xml_to_tokens_to_xml ___________________________
#
# ...
